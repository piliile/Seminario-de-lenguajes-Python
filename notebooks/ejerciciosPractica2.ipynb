# %%
import sys
sys.path.append('../src')

# %% [markdown]
# # Práctica 2 - Python
# ### Pilar Leban 26189/0

# %% [markdown]
# # Ejercicio 1
# ## Estadísticas de un texto
# #### Dado el siguiente texto almacenado en una variable, calcule e imprima:
# - La cantidad total de líneas.
# - La cantidad total de palabras.
# - El promedio de palabras por línea.
# - Todas las líneas cuya cantidad de palabras esté por encima del promedio

# %%
import ejercicio1

text = """Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way
to do it.
Although that way may not be obvious at first unless you're
Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good
idea.
Namespaces are one honking great idea -- let's do more of
those!"""

cantLineas = ejercicio1.cantidadLineas(text)
print(f"La cantidad total de líneas es:  {cantLineas}")

cantPalabras = ejercicio1.cantidadPalabras(text)
print(f"La cantidad de palabras es: {cantPalabras}")

promedio = ejercicio1.promedioPalabras(text)
print(f"El promedio de palabras por línea es: {promedio}")

lineasEncimaProm = ejercicio1.lineasEncimaPromedio(text)
print(f"La cantidad de líneas por encima del promedio es: {lineasEncimaProm}")
# Out:
# La cantidad total de líneas es:  23
# La cantidad de palabras es: 137
# El promedio de palabras por línea es: 5.956521739130435
# La cantidad de líneas por encima del promedio es: ["Special cases aren't special enough to break the rules.", 'In the face of ambiguity, refuse the temptation to guess.', 'There should be one-- and preferably only one --obvious way', "Although that way may not be obvious at first unless you're", 'Although never is often better than *right* now.', "If the implementation is hard to explain, it's a bad idea.", 'If the implementation is easy to explain, it may be a good', "Namespaces are one honking great idea -- let's do more of"]

# %% [markdown]
# # Ejercicio 2
# ## Duración de una playlist
# ##### Dada la siguiente playlist con canciones y sus duraciones en formato "m:ss":

# %%
import ejercicio2

playlist = [
{"title": "Bohemian Rhapsody", "duration": "5:55"},
{"title": "Hotel California", "duration": "6:30"},
{"title": "Stairway to Heaven", "duration": "8:02"},
{"title": "Imagine", "duration": "3:07"},
{"title": "Smells Like Teen Spirit", "duration": "5:01"},
{"title": "Billie Jean", "duration": "4:54"},
{"title": "Hey Jude", "duration": "7:11"},
{"title": "Like a Rolling Stone", "duration": "6:13"},
]

cancionMasLarga = ejercicio2.cancionLarga(playlist)
cancionMasCorta = ejercicio2.cancionCorta(playlist)
duracionTotal = ejercicio2.duracionTot(playlist)
print(f"Duración total: {duracionTotal}")
print(f"Canción más larga: {cancionMasLarga}")
print(f"Canción más corta: {cancionMasCorta}")
# Out:
# Duración total: 46m 53s
# Canción más larga: "Stairway to Heaven" (8:02)
# Canción más corta: "Imagine" (3:07)

# %% [markdown]
# ##### Calcule la duración total de la playlist en formato Xm Ys, y encuentre la canción más larga y la más corta.
# ##### Nota: Deberá convertir las duraciones de string a valores numéricos para poder operar con ellas.
# ##### Salida esperada:
# ##### Duración total: 46m 53s
# ##### Canción más larga: "Stairway to Heaven" (8:02)
# ##### Canción más corta: "Imagine" (3:07)

# %% [markdown]
# # Ejercicio 3
# ##### Dada la siguiente reseña de una película: Solicite al usuario una lista de palabras consideradas spoilers (separadas por coma). El programa debe reemplazar todas las apariciones de esas palabras en el texto por asteriscos (*) de la misma longitud, sin distinguir mayúsculas de minúsculas.

# %%
import ejercicio3

review = """La película sigue a un grupo de astronautas que viajan a Marte
en una misión de rescate. El capitán Torres lidera al equipo a través
de tormentas solares y fallos en el sistema de navegación. Al llegar
a Marte descubren que la base está abandonada y los suministros
destruidos. Torres decide sacrificar la nave nodriza para salvar
al equipo y logran volver a la Tierra en una cápsula de emergencia.
El final revela que Torres sobrevivió gracias a un pasaje
secreto."""

palabrasSpoiler = input("Ingrese palabras spoiler (separadas por coma):  ")
reviewSinSpoiler = ejercicio3.censurarSpoiler(review, palabrasSpoiler)
reviewSinSpoiler
# Out:
# 'La película sigue a un grupo de astronautas que viajan a Marte en una misión de rescate. El capitán Torres lidera al equipo a través de tormentas solares y fallos en el sistema de navegación. Al llegar a Marte descubren que la base está abandonada y los suministros destruidos. Torres decide sacrificar la nave nodriza para salvar al equipo y logran volver a la Tierra en una cápsula de emergencia. El final revela que Torres sobrevivió gracias a un pasaje secreto.'

# %% [markdown]
# ##### Ejemplo de entrada y salida esperada:
# ##### Ingrese las palabras spoiler (separadas por coma): Marte, Torres, sacrificar, sobrevivió.
# ##### La película sigue a un grupo de astronautas que viajan a ***
# ##### en una misión de rescate. El capitán *** lidera al equipo a través
# ##### de tormentas solares y fallos en el sistema de navegación. Al llegar
# ##### a *** descubren que la base está abandonada y los suministros
# ##### destruidos. *** decide ** la nave nodriza para salvar
# ##### al equipo y logran volver a la Tierra en una cápsula de emergencia.
# ##### El final revela que *** ** gracias a un pasaje secreto.

# %% [markdown]
# # Ejercicio 4
# ## Validación de email
# ##### Valide una dirección de email ingresada por el usuario con los siguientes criterios:
# - Contiene exactamente un @.
# - Tiene al menos un carácter antes del @.
# - Tiene al menos un punto (.) después del @.
# - No empieza ni termina con @ ni con ..
# - La parte después del último punto tiene al menos 2 caracteres (el dominio).

# %%
import ejercicio4

email = input("Ingrese una dirección de email: ")
validacionFinal = ejercicio4.validar(email)
validacionFinal
# Out:
# 'El email no es válido.'

# %% [markdown]
# ##### Ejemplo de entrada y salida esperada:
# ##### Ingrese un email: 'usuario@ejemplo.com'
# ##### El email es válido.
# ##### Ingrese un email: @ejemplo.com
# ##### El email no es válido.
# ##### Ingrese un email: usuario@ejemplo
# ##### El email no es válido.

# %% [markdown]
# # Ejercicio 5
# ## Calculadora de costo de envío
# ##### Calcule el costo de envío de un paquete según su peso (en kg) y la zona de destino. El usuario debe ingresar ambos valores.
# ##### Las zonas válidas son: local, regional, nacional.
# ##### Peso / Zona    Local Regional Nacional
# ##### Hasta 1 kg     $500  $1000    $2000
# ##### Entre 1 y 5 kg $1000 $2500 $4500
# ##### Más de 5 kg    $2000 $5000 $8000
# ##### Si la zona no es válida, debe indicar el error

# %%
import ejercicio5
pesoPaquete = input("Ingrese el peso de su paquete: ")
zonaDestino = input("Ingrese la zona de destino de su paquete: ").lower()
print(f"Costo de envío: {ejercicio5.calcularCosto(pesoPaquete, zonaDestino)}")

# %% [markdown]
# ##### Ejemplo de salida esperada:
# ##### Ingrese el peso del paquete (kg): 3.5
# ##### Ingrese la zona de destino (local/regional/nacional): regional
# ##### Costo de envío: $2500
# ##### Ingrese el peso del paquete (kg): 0.5
# ##### Ingrese la zona de destino (local/regional/nacional): internacional
# ##### Zona no válida. Las zonas disponibles son: local, regional, nacional.

# %% [markdown]
# # Ejercicio 6
# ## Análisis de hashtags
# ##### Dadas las siguientes publicaciones de una red social, extraiga todos los # hashtags (palabras que comienzan con #), cuente la frecuencia de cada uno, y muestre los hashtags trending (los que aparecen más de una vez).

# %%
import ejercicio6
posts = [
"Arrancando el lunes con energía #Motivación #NuevaSemana ",
"Terminé mi primer proyecto en Python #Python #Programación #OrgullosoDeMi ",
"No puedo creer el final de la serie #SinSpoilers #SerieAdicta ",
"Nuevo video en el canal sobre #InteligenciaArtificial y #Python ",
"Entrenamiento de hoy completado #Fitness #Motivación #NoPainNoGain ",
"Leyendo sobre #InteligenciaArtificial y el futuro del trabajo #Tecnología ",
"Arranqué a estudiar #Programación por mi cuenta #Python #Autodidacta ",
"Finde de lluvia, maratón de series #SerieAdicta #Relax",
"Workshop de #InteligenciaArtificial en la universidad #Tecnología #Programación "
]

print(f"Hashtag trending (más de una aparición): {ejercicio6.hashtagsTrending(posts)}")
print(f"Total de hashtags únicos: {ejercicio6.hashtagsUnicos(posts)}")
# Out:
# Hashtag trending (más de una aparición):
#  #Motivación: 2
#  #Python: 3
#  #Programación: 3
#  #SerieAdicta: 2
#  #InteligenciaArtificial: 3
#  #Tecnología: 2
# Total de hashtags únicos: 13

# %% [markdown]
# ##### Salida esperada:
# ##### Hashtags trending (más de una aparición):
# #####   #Python: 3
# #####   #Programación: 3
# #####   #InteligenciaArtificial: 3
# #####   #Motivación: 2
# #####   #SerieAdicta: 2
# #####   #Tecnología: 2
# ##### Total de hashtags únicos: 13

# %% [markdown]
# # Ejercicio 7
# ## Sorteo de amigo invisible
# ##### Solicite al usuario una lista de nombres de participantes (separados por coma). El programa debe asignar aleatoriamente a cada persona un amigo invisible, cumpliendo que nadie se tenga a sí mismo.
# ##### Validaciones:
# - Debe haber al menos 3 participantes.
# - No debe haber nombres duplicados (comparar ignorando mayúsculas y espacios extra).

# %%
import ejercicio7


nombresParticipantes = input("Ingrese el nombre de los participantes: ")
asignacion = ejercicio7.asignarParticipantes(nombresParticipantes)
asignacion

# %% [markdown]
# ##### Ingrese los participantes (separados por coma): Ana, Pedro, Lucía, Mateo, Sorteo de amigo invisible:
# ##### Ana → Mateo
# ##### Pedro → Sofía
# ##### Lucía → Ana
# ##### Mateo → Pedro
# ##### Sofía → Lucía
# ##### Nota: Los resultados varían en cada ejecución por ser aleatorios, pero ninguna persona debe tenerse a sí misma.

# %% [markdown]
# # Ejercicio 8
# ## Cifrado César
# ##### Implemente el cifrado César, que consiste en desplazar cada letra del alfabeto una cantidad fija de posiciones. El programa debe:
# - Solicitar un mensaje al usuario.
# - Solicitar un valor de desplazamiento (número entero).
# - Mostrar el mensaje cifrado.
# - Mostrar el mensaje descifrado a partir del cifrado (para verificar que funciona).
# ##### Las letras deben rotar (después de la Z viene la A). Los caracteres que no sean letras (espacios, signos de puntuación, números) se mantienen sin cambios. Debe funcionar tanto con mayúsculas como con minúsculas, preservando el formato original.

# %%
import ejercicio8
mensajeDelUsuario = input("Ingrese el mensaje: ")
valorDeDesplazamiento = int(input("Ingrese el valor del desplazamiento: "))
cifrado = ejercicio8.mostrarMensajeCifrado(mensajeDelUsuario, valorDeDesplazamiento)
print(f"Mensaje cifrado: {cifrado}")
descifrado = ejercicio8.mostrarMensajeCifrado(cifrado, -valorDeDesplazamiento)
print(f"Mensaje descifrado: {descifrado}")

# %% [markdown]
# ##### Ejemplo de entrada y salida esperada:
# ##### Ingrese un mensaje: Hola Mundo!
# ##### Ingrese el desplazamiento: 3
# ##### Mensaje cifrado: Krod Pxqgr!
# ##### Mensaje descifrado: Hola Mundo!

# %% [markdown]
# # Ejercicio 9
# ## Normalización de registros de alumnos
# ##### Eres ayudante en una cátedra que recibió registros de alumnos desde múltiples fuentes. Los datos llegaron con errores: nombres con formatos inconsistentes, notas faltantes, registros nulos y alumnos duplicados con distintas notas.
# ##### Tu tarea es limpiar los datos y generar un listado final.
# ##### Debe realizar las siguientes operaciones:
# - Eliminar registros con nombre nulo, vacío o solo espacios.
# - Eliminar registros con nota nula, vacía o no numérica (como "absent").
# - Normalizar nombres a formato título y estados a formato título.
# - Eliminar duplicados por nombre, quedándose con la nota más alta de cada alumno.
# -Ordenar alfabéticamente por nombre.

# %%
import ejercicio9

students = [
{"name": " Ana García ", "grade": "8", "status":
"aprobado"},
{"name": "pedro lópez", "grade": "4", "status":
"DESAPROBADO"},
{"name": "MARÍA FERNÁNDEZ", "grade": "10", "status":
"Aprobado"},
{"name": "ana garcía", "grade": "9", "status":
"aprobado"},
{"name": None, "grade": "7", "status": "aprobado"},
{"name": "Luis Martínez ", "grade": None, "status":
"aprobado"},
{"name": " carlos RUIZ", "grade": "6", "status":
"aprobado"},
{"name": "PEDRO LÓPEZ ", "grade": "3", "status":
"desaprobado"},
{"name": " ", "grade": "5", "status": "aprobado"},
{"name": "María Fernández", "grade": "7", "status":
"APROBADO"},
{"name": "Sofía Torres", "grade": "9", "status":
"Aprobado"},
{"name": " sofía torres ", "grade": "8", "status":
"aprobado"},
{"name": "Carlos Ruiz", "grade": "6", "status":
"APROBADO"},
{"name": "Roberto Díaz", "grade": "absent", "status":
"ausente"},
{"name": "roberto díaz", "grade": "", "status":
"Ausente"},
{"name": None, "grade": None, "status": None},
{"name": "Laura Méndez", "grade": "7", "status":
"aprobado"},
{"name": " laura méndez", "grade": "8", "status":
"Aprobado"},
{"name": "GABRIELA RÍOS", "grade": "5", "status":
"aprobado"},
{"name": "gabriela ríos ", "grade": "4", "status":
"Desaprobado"},
]
listadoFinal = ejercicio9.armarListadoFinal(students)
print(f" Registros limpios de alumnos {listadoFinal}")
print(f"Total de alumnos válidos: {len(listadoFinal)}")
# corregir como imprimirlo correctamente
# Out:
#  Registros limpios de alumnos [{'Nombre': 'Ana García', 'Nota': 10, 'Estado': 'Aprobado'}, {'Nombre': 'Carlos Ruiz', 'Nota': 9, 'Estado': 'Aprobado'}, {'Nombre': 'Gabriela Ríos', 'Nota': 5, 'Estado': 'Aprobado'}, {'Nombre': 'Laura Méndez', 'Nota': 8, 'Estado': 'Aprobado'}, {'Nombre': 'María Fernández', 'Nota': 10, 'Estado': 'Aprobado'}, {'Nombre': 'Pedro López', 'Nota': 10, 'Estado': 'Aprobado'}, {'Nombre': 'Sofía Torres', 'Nota': 9, 'Estado': 'Aprobado'}]
# Total de alumnos válidos: 7

# %% [markdown]
# ##### Registros limpios de alumnos:
# ##### Nombre        Nota        Estado
# ------------------------------------------
# ##### Ana García     9          Aprobado
# ##### Carlos Ruiz    6          Aprobado
# ##### Gabriela Ríos  5          Aprobado
# ##### Laura Méndez   8          Aprobado
# ##### María Fernández 10        Aprobado
# ##### Pedro López    4          Desaprobado
# ##### Sofía Torres   9          Aprobado
#
# ##### Total de alumnos válidos: 7
